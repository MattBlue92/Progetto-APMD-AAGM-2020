# %% [markdown]
# ## Building the graph

# %%
import networkx as nx
import numpy as np
import pandas as pd

# %%
import os
from path import Path
PROJ_DIR = Path().getcwd().parent
DATA_DIR = PROJ_DIR / "data"
os.chdir (PROJ_DIR)

# %%
from scripts.src.BuiderGraphWithRtree import BuilderGraphWithRtree
from scripts.src.BuilderGraphNearestNeighbors import BuilderGraphNearestNeighbors
from scripts.src.BuilderGraph import BuilderGraph
from scripts.src.BuilderGraphWithMerge import BuilderGraphWithMerge

# %%
import json

with open(DATA_DIR/'dpc-covid19-ita-province.json') as f:
         d= json.load(f) 
json.dumps(d)
covid19_dataset=pd.DataFrame(d)
covid19_dataset.head()
# Out:
#                   data stato  codice_regione denominazione_regione  \
# 0  2020-02-24T18:00:00   ITA              13               Abruzzo
# 1  2020-02-24T18:00:00   ITA              13               Abruzzo
# 2  2020-02-24T18:00:00   ITA              13               Abruzzo
# 3  2020-02-24T18:00:00   ITA              13               Abruzzo
# 4  2020-02-24T18:00:00   ITA              13               Abruzzo
#
#    codice_provincia               denominazione_provincia sigla_provincia  \
# 0                69                                Chieti              CH
# 1                66                              L'Aquila              AQ
# 2                68                               Pescara              PE
# 3                67                                Teramo              TE
# 4               979  In fase di definizione/aggiornamento
#
#          lat       long  totale_casi note_it note_en
# 0  42.351032  14.167546            0
# 1  42.351222  13.398438            0
# 2  42.464584  14.213648            0
# 3  42.658918  13.704400            0
# 4   0.000000   0.000000            0

# %%
covid19_dataset.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione',
#        'codice_provincia', 'denominazione_provincia', 'sigla_provincia', 'lat',
#        'long', 'totale_casi', 'note_it', 'note_en'],
#       dtype='object')

# %%
covid19_dataset.drop_duplicates(subset=['denominazione_provincia'],inplace=True)

# %%
covid19_dataset.head(20)
# Out:
#                    data stato  codice_regione denominazione_regione  \
# 0   2020-02-24T18:00:00   ITA              13               Abruzzo
# 1   2020-02-24T18:00:00   ITA              13               Abruzzo
# 2   2020-02-24T18:00:00   ITA              13               Abruzzo
# 3   2020-02-24T18:00:00   ITA              13               Abruzzo
# 4   2020-02-24T18:00:00   ITA              13               Abruzzo
# 5   2020-02-24T18:00:00   ITA              17            Basilicata
# 6   2020-02-24T18:00:00   ITA              17            Basilicata
# 8   2020-02-24T18:00:00   ITA              21          P.A. Bolzano
# 10  2020-02-24T18:00:00   ITA              18              Calabria
# 11  2020-02-24T18:00:00   ITA              18              Calabria
# 12  2020-02-24T18:00:00   ITA              18              Calabria
# 13  2020-02-24T18:00:00   ITA              18              Calabria
# 14  2020-02-24T18:00:00   ITA              18              Calabria
# 16  2020-02-24T18:00:00   ITA              15              Campania
# 17  2020-02-24T18:00:00   ITA              15              Campania
# 18  2020-02-24T18:00:00   ITA              15              Campania
# 19  2020-02-24T18:00:00   ITA              15              Campania
# 20  2020-02-24T18:00:00   ITA              15              Campania
# 22  2020-02-24T18:00:00   ITA               8        Emilia-Romagna
# 23  2020-02-24T18:00:00   ITA               8        Emilia-Romagna
#
#     codice_provincia               denominazione_provincia sigla_provincia  \
# 0                 69                                Chieti              CH
# 1                 66                              L'Aquila              AQ
# 2                 68                               Pescara              PE
# 3                 67                                Teramo              TE
# 4                979  In fase di definizione/aggiornamento
# 5                 77                                Matera              MT
# 6                 76                               Potenza              PZ
# 8                 21                               Bolzano              BZ
# 10                79                             Catanzaro              CZ
# 11                78                               Cosenza              CS
# 12               101                               Crotone              KR
# 13                80                    Reggio di Calabria              RC
# 14               102                         Vibo Valentia              VV
# 16                64                              Avellino              AV
# 17                62                             Benevento              BN
# 18                61                               Caserta              CE
# 19                63                                Napoli              NA
# 20                65                               Salerno              SA
# 22                37                               Bologna              BO
# 23                38                               Ferrara              FE
#
#           lat       long  totale_casi note_it note_en
# 0   42.351032  14.167546            0
# 1   42.351222  13.398438            0
# 2   42.464584  14.213648            0
# 3   42.658918  13.704400            0
# 4    0.000000   0.000000            0
# 5   40.667512  16.597924            0
# 6   40.639471  15.805148            0
# 8   46.499335  11.356624            0
# 10  38.905976  16.594402            0
# 11  39.293087  16.256097            0
# 12  39.080369  17.125389            0
# 13  38.109228  15.643453            0
# 14  38.676241  16.101574            0
# 16  40.914047  14.795288            0
# 17  41.129700  14.781517            0
# 18  41.074659  14.332405            0
# 19  40.839566  14.250850            0
# 20  40.678220  14.759403            0
# 22  44.494367  11.341721            0
# 23  44.835991  11.618689            0

# %%
provincia = covid19_dataset['denominazione_provincia']
lat = covid19_dataset['lat']
long = covid19_dataset['long']
province = pd.DataFrame(data = {'citta': provincia, 'lat': lat, 'long':long})
province.head()
# Out:
#                                   citta        lat       long
# 0                                Chieti  42.351032  14.167546
# 1                              L'Aquila  42.351222  13.398438
# 2                               Pescara  42.464584  14.213648
# 3                                Teramo  42.658918  13.704400
# 4  In fase di definizione/aggiornamento   0.000000   0.000000

# %%
builderGraph1 = BuilderGraph(0.8)
temp=province.copy()
graph = builderGraph1.buildGraph(temp)

nx.draw(graph,with_labels=True)

# %%
builderGraph2=BuilderGraphWithMerge(0.8)
temp=province.copy()
graph1=builderGraph2.buildGraph(temp)
nx.is_isomorphic(graph, graph1)
# Out:
# True

# %%
builderGraph3=BuilderGraphNearestNeighbors(0.8)
temp=province.copy()
graph1=builderGraph3.buildGraph(temp)
nx.is_isomorphic(graph, graph1)
# Out:
# False

# %%
print(graph.edges())
print(graph1.edges())
# Out:
# [('Chieti', 'Chieti'), ('Chieti', "L'Aquila"), ('Chieti', 'Pescara'), ('Chieti', 'Teramo'), ('Chieti', 'Ascoli Piceno'), ('Chieti', 'Campobasso'), ('Chieti', 'Isernia'), ("L'Aquila", "L'Aquila"), ("L'Aquila", 'Teramo'), ("L'Aquila", 'Frosinone'), ("L'Aquila", 'Rieti'), ("L'Aquila", 'Ascoli Piceno'), ("L'Aquila", 'Terni'), ('Pescara', 'Pescara'), ('Pescara', 'Teramo'), ('Pescara', 'Ascoli Piceno'), ('Pescara', 'Fermo'), ('Teramo', 'Teramo'), ('Teramo', 'Ascoli Piceno'), ('Teramo', 'Fermo'), ('Teramo', 'Macerata'), ('In fase di definizione/aggiornamento', 'In fase di definizione/aggiornamento'), ('Matera', 'Matera'), ('Matera', 'Potenza'), ('Matera', 'Bari'), ('Matera', 'Barletta-Andria-Trani'), ('Matera', 'Taranto'), ('Potenza', 'Potenza'), ('Potenza', 'Barletta-Andria-Trani'), ('Bolzano', 'Bolzano'), ('Bolzano', 'Trento'), ('Catanzaro', 'Catanzaro'), ('Catanzaro', 'Cosenza'), ('Catanzaro', 'Crotone'), ('Catanzaro', 'Vibo Valentia'), ('Cosenza', 'Cosenza'), ('Cosenza', 'Vibo Valentia'), ('Crotone', 'Crotone'), ('Reggio di Calabria', 'Reggio di Calabria'), ('Reggio di Calabria', 'Vibo Valentia'), ('Reggio di Calabria', 'Catania'), ('Reggio di Calabria', 'Messina'), ('Vibo Valentia', 'Vibo Valentia'), ('Vibo Valentia', 'Messina'), ('Avellino', 'Avellino'), ('Avellino', 'Benevento'), ('Avellino', 'Caserta'), ('Avellino', 'Napoli'), ('Avellino', 'Salerno'), ('Avellino', 'Campobasso'), ('Avellino', 'Isernia'), ('Avellino', 'Foggia'), ('Benevento', 'Benevento'), ('Benevento', 'Caserta'), ('Benevento', 'Napoli'), ('Benevento', 'Salerno'), ('Benevento', 'Campobasso'), ('Benevento', 'Isernia'), ('Benevento', 'Foggia'), ('Caserta', 'Caserta'), ('Caserta', 'Napoli'), ('Caserta', 'Salerno'), ('Caserta', 'Campobasso'), ('Caserta', 'Isernia'), ('Napoli', 'Napoli'), ('Napoli', 'Salerno'), ('Napoli', 'Campobasso'), ('Napoli', 'Isernia'), ('Salerno', 'Salerno'), ('Salerno', 'Foggia'), ('Bologna', 'Bologna'), ('Bologna', 'Ferrara'), ('Bologna', 'ForlÃ¬-Cesena'), ('Bologna', 'Modena'), ('Bologna', "Reggio nell'Emilia"), ('Bologna', 'Mantova'), ('Bologna', 'Firenze'), ('Bologna', 'Pistoia'), ('Bologna', 'Prato'), ('Bologna', 'Rovigo'), ('Ferrara', 'Ferrara'), ('Ferrara', 'ForlÃ¬-Cesena'), ('Ferrara', 'Modena'), ('Ferrara', 'Ravenna'), ('Ferrara', 'Padova'), ('Ferrara', 'Rovigo'), ('Ferrara', 'Venezia'), ('Ferrara', 'Verona'), ('Ferrara', 'Vicenza'), ('ForlÃ¬-Cesena', 'ForlÃ¬-Cesena'), ('ForlÃ¬-Cesena', 'Ravenna'), ('ForlÃ¬-Cesena', 'Rimini'), ('ForlÃ¬-Cesena', 'Arezzo'), ('ForlÃ¬-Cesena', 'Firenze'), ('Modena', 'Modena'), ('Modena', 'Parma'), ('Modena', "Reggio nell'Emilia"), ('Modena', 'Mantova'), ('Modena', 'Massa Carrara'), ('Modena', 'Pistoia'), ('Modena', 'Prato'), ('Modena', 'Verona'), ('Parma', 'Parma'), ('Parma', 'Piacenza'), ('Parma', "Reggio nell'Emilia"), ('Parma', 'La Spezia'), ('Parma', 'Brescia'), ('Parma', 'Cremona'), ('Parma', 'Mantova'), ('Parma', 'Massa Carrara'), ('Parma', 'Verona'), ('Piacenza', 'Piacenza'), ('Piacenza', 'Genova'), ('Piacenza', 'Bergamo'), ('Piacenza', 'Brescia'), ('Piacenza', 'Como'), ('Piacenza', 'Cremona'), ('Piacenza', 'Lodi'), ('Piacenza', 'Milano'), ('Piacenza', 'Monza e della Brianza'), ('Piacenza', 'Pavia'), ('Ravenna', 'Ravenna'), ('Ravenna', 'Rimini'), ('Ravenna', 'Pesaro e Urbino'), ('Ravenna', 'Rovigo'), ("Reggio nell'Emilia", "Reggio nell'Emilia"), ("Reggio nell'Emilia", 'Cremona'), ("Reggio nell'Emilia", 'Mantova'), ("Reggio nell'Emilia", 'Massa Carrara'), ("Reggio nell'Emilia", 'Pistoia'), ("Reggio nell'Emilia", 'Verona'), ('Rimini', 'Rimini'), ('Rimini', 'Pesaro e Urbino'), ('Rimini', 'Arezzo'), ('Gorizia', 'Gorizia'), ('Gorizia', 'Trieste'), ('Gorizia', 'Udine'), ('Pordenone', 'Pordenone'), ('Pordenone', 'Udine'), ('Pordenone', 'Belluno'), ('Pordenone', 'Padova'), ('Pordenone', 'Treviso'), ('Pordenone', 'Venezia'), ('Trieste', 'Trieste'), ('Trieste', 'Udine'), ('Udine', 'Udine'), ('Frosinone', 'Frosinone'), ('Frosinone', 'Latina'), ('Frosinone', 'Rieti'), ('Latina', 'Latina'), ('Latina', 'Roma' ...
# [('Chieti', 'Chieti'), ('Chieti', 'Pescara'), ('Chieti', 'Isernia'), ('Chieti', 'Napoli'), ('Chieti', 'Caltanissetta'), ('Chieti', 'Enna'), ('Chieti', 'Caserta'), ('Chieti', 'Trieste'), ('Chieti', 'Fermo'), ('Chieti', 'Teramo'), ('Chieti', 'Campobasso'), ('Chieti', 'Gorizia'), ('Chieti', 'Ragusa'), ('Chieti', 'Agrigento'), ('Chieti', 'Ascoli Piceno'), ('Chieti', 'Salerno'), ('Chieti', 'Benevento'), ('Chieti', 'Avellino'), ('Chieti', 'Ancona'), ('Chieti', 'Macerata'), ('Chieti', "L'Aquila"), ('Pescara', 'Pescara'), ('Pescara', 'Isernia'), ('Pescara', 'Napoli'), ('Pescara', 'Enna'), ('Pescara', 'Caserta'), ('Pescara', 'Caltanissetta'), ('Pescara', 'Trieste'), ('Pescara', 'Campobasso'), ('Pescara', 'Fermo'), ('Pescara', 'Teramo'), ('Pescara', 'Ragusa'), ('Pescara', 'Salerno'), ('Pescara', 'Benevento'), ('Pescara', 'Avellino'), ('Pescara', 'Gorizia'), ('Pescara', 'Agrigento'), ('Pescara', 'Ascoli Piceno'), ('Pescara', 'Ancona'), ('Pescara', 'Macerata'), ('Isernia', 'Teramo'), ('Isernia', 'Avellino'), ('Isernia', 'Benevento'), ('Isernia', 'Caserta'), ('Isernia', 'Napoli'), ('Isernia', 'Salerno'), ('Isernia', 'Gorizia'), ('Isernia', 'Trieste'), ('Isernia', 'Ancona'), ('Isernia', 'Ascoli Piceno'), ('Isernia', 'Fermo'), ('Isernia', 'Macerata'), ('Isernia', 'Campobasso'), ('Isernia', 'Isernia'), ('Isernia', 'Enna'), ('Isernia', 'Caltanissetta'), ('Isernia', 'Ragusa'), ('Isernia', 'Agrigento'), ('Napoli', 'Teramo'), ('Napoli', 'Avellino'), ('Napoli', 'Benevento'), ('Napoli', 'Caserta'), ('Napoli', 'Napoli'), ('Napoli', 'Enna'), ('Napoli', 'Caltanissetta'), ('Napoli', 'Campobasso'), ('Napoli', 'Ragusa'), ('Napoli', 'Trieste'), ('Napoli', 'Salerno'), ('Napoli', 'Fermo'), ('Napoli', 'Gorizia'), ('Napoli', 'Agrigento'), ('Napoli', 'Ascoli Piceno'), ('Napoli', 'Ancona'), ('Napoli', 'Macerata'), ('Caltanissetta', "L'Aquila"), ('Caltanissetta', 'Teramo'), ('Caltanissetta', 'Avellino'), ('Caltanissetta', 'Benevento'), ('Caltanissetta', 'Caserta'), ('Caltanissetta', 'Salerno'), ('Caltanissetta', 'Gorizia'), ('Caltanissetta', 'Trieste'), ('Caltanissetta', 'Frosinone'), ('Caltanissetta', 'Ancona'), ('Caltanissetta', 'Ascoli Piceno'), ('Caltanissetta', 'Fermo'), ('Caltanissetta', 'Macerata'), ('Caltanissetta', 'Campobasso'), ('Caltanissetta', 'Agrigento'), ('Caltanissetta', 'Caltanissetta'), ('Caltanissetta', 'Enna'), ('Caltanissetta', 'Ragusa'), ('Caltanissetta', 'Palermo'), ('Enna', 'Teramo'), ('Enna', 'Avellino'), ('Enna', 'Benevento'), ('Enna', 'Caserta'), ('Enna', 'Salerno'), ('Enna', 'Gorizia'), ('Enna', 'Trieste'), ('Enna', 'Ancona'), ('Enna', 'Ascoli Piceno'), ('Enna', 'Fermo'), ('Enna', 'Campobasso'), ('Enna', 'Agrigento'), ('Enna', 'Enna'), ('Enna', 'Ragusa'), ('Caserta', 'Teramo'), ('Caserta', 'Avellino'), ('Caserta', 'Benevento'), ('Caserta', 'Caserta'), ('Caserta', 'Campobasso'), ('Caserta', 'Ragusa'), ('Caserta', 'Salerno'), ('Caserta', 'Trieste'), ('Caserta', 'Fermo'), ('Caserta', 'Gorizia'), ('Caserta', 'Agrigento'), ('Caserta', 'Catania'), ('Caserta', 'Ascoli Piceno'), ('Trieste', "L'Aquila"), ('Trieste', 'Teramo'), ('Trieste', 'Gorizia'), ('Trieste', 'Trieste'), ('Trieste', 'Fermo'), ('Trieste', 'Agrigento'), ('Trieste', 'Ascoli Piceno'), ('Trieste', 'Ancona'), ('Trieste', 'Macerata'), ('Trieste', 'Palermo'), ('Trieste', 'Frosinone'), ('Trieste', 'Udine'), ('Fermo', "L'Aquila"), ('Fermo', 'Teramo'), ('Fermo', 'Gorizia'), ('Fermo', 'Udine'), ('Fermo', 'Frosinone'), ('Fermo', 'Ancona'), ('Fermo', 'Ascoli Piceno'), ('Fermo', 'Fermo'), ('Fermo', 'Agrigento'), ('Fermo', 'Macerata'), ('Fermo', 'Palermo'), ('Teramo', "L'Aquila"), ('Teramo', 'Teramo'), ('Teramo', 'Gorizia'), ('Teramo', 'Agrigento'), ('Teramo', 'Ascoli Piceno'), ('Teramo', 'Ancona'), ('Teramo', 'Macerata'), ('Teramo', 'Palermo'), ('Teramo', 'Frosinone'), ('Teramo', 'Udine'), ('Teramo', 'Pesaro e Urbino'), ('Campobasso', 'Avellino'), ('Campobasso', 'Benevento'), ('Campobasso', 'Salerno'), ('Campobasso', 'Campobasso'), ('Campobasso', 'Ragusa'), ('Campobasso', 'Catania'), ('C ...

# %%
builderGraph4=BuilderGraphWithRtree(0.8, long.values, lat.values, provincia.values)
graph1=builderGraph4.intersection()
nx.is_isomorphic(graph, graph1)
# Out:
# True

# %%
temp=province.copy()
# %timeit builderGraph1.buildGraph(temp)
# Out:
# 21 ms ± 4.94 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
temp=province.copy()
# %timeit builderGraph2.buildGraph(temp)
# Out:
# 618 ms ± 56.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
temp=province.copy()
# %timeit builderGraph3.buildGraph(temp)
# Out:
# 340 ms ± 12.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit new_r_tree_graph_creation(long.values, lat.values, provincia.values)
# Out:
# 44.9 ms ± 2.77 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit builderGraph4.intersection()
# Out:
# 46 ms ± 6.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
