# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a=np.random.randn(10)
b=np.random.randn(10)
plt.plot(a, b)

# %%
assert 1==0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-fccf73b60bdb> in <module>
# ----> 1 assert 1==0
#       2
#
# AssertionError:
